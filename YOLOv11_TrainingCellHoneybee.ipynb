# %% [markdown]
# <a href="https://colab.research.google.com/github/bnsreenu/python_for_microscopists/blob/master/334_training_YOLO_V8_EM_platelets_converted_labels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Check GPU

# %%
import torch

print("Number of GPU: ", torch.cuda.device_count())
print("GPU Name: ", torch.cuda.get_device_name())


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)

# %% [markdown]
# -----

# %% [markdown]
# **Train the model**

# %% [markdown]
# ---
# 960

# %%
import torch
print(torch.cuda.is_available())

if 'model' in globals():
    del model
    
torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
import os
from ultralytics import YOLO
from matplotlib import pyplot as plt
from PIL import Image

import torch


#Define a where is the destination directory for result
project = "E:\\University\\Finalproject\BeeCount\\Main\\Yolo\\Results\\960"
#Define subdirectory for this specific training
name = "full_200_epochs_170_batch_4" 

# Load a model
model = YOLO("yolo11s-seg.yaml")  # build a new model from YAML
model = YOLO("yolo11s-seg.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11s-seg.yaml").load("yolo11s.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data='your path\\data.yaml',
                      project=project, #Define a where is the destination directory for result
                      name=name, #Define subdirectory for this specific training
                      epochs=200,
                      patience=0, #setting patience=0 to disable early stopping.
                      batch=4,
                      imgsz=960,  
                    )

# %% [markdown]
# ---
# 800

# %%
import torch
print(torch.cuda.is_available())

if 'model' in globals():
    del model

torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
import os
from ultralytics import YOLO
# %matplotlib inline
from matplotlib import pyplot as plt
from PIL import Image

import torch


#Define a project --> Destination directory for all results
project = "E:\\University\\Finalproject\BeeCount\\Main\\Yolo\\Results\\800"
#Define subdirectory for this specific training
name = "full_200_epochs_171_batch_4" 

# Load a model
model = YOLO("yolo11s-seg.yaml")  # build a new model from YAML
model = YOLO("yolo11s-seg.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11s-seg.yaml").load("yolo11s.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data='E:\\University\\Finalproject\BeeCount\\Main\\Yolo\\Dataset\\80.10.10\\G3awE7I0R3Z2.v171i.yolov11\\data.yaml',
                      project=project,
                      name=name,
                      epochs=200,
                      patience=0, #setting patience=0 to disable early stopping.
                      batch=4,
                      imgsz=800,  
                    )

# %% [markdown]
# ---
# 640

# %%
import torch
print(torch.cuda.is_available())

if 'model' in globals():
    del model

torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
import os
from ultralytics import YOLO
# %matplotlib inline
from matplotlib import pyplot as plt
from PIL import Image

import torch


#Define a project --> Destination directory for all results
project = "E:\\University\\Finalproject\BeeCount\\Main\\Yolo\\Results\\640"
#Define subdirectory for this specific training
name = "full_200_epochs_172_batch_4" 

# Load a model
model = YOLO("yolo11s-seg.yaml")  # build a new model from YAML
model = YOLO("yolo11s-seg.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11s-seg.yaml").load("yolo11s.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data='E:\\University\\Finalproject\BeeCount\\Main\\Yolo\\Dataset\\80.10.10\\G3awE7I0R3Z2.v172i.yolov11\\data.yaml',
                      project=project,
                      name=name,
                      epochs=200,
                      patience=0, #setting patience=0 to disable early stopping.
                      batch=4,
                      imgsz=640,  
                    )

# %% [markdown]
# ---
# 512

# %%
import torch
print(torch.cuda.is_available())

if 'model' in globals():
    del model

torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
import os
from ultralytics import YOLO
# %matplotlib inline
from matplotlib import pyplot as plt
from PIL import Image

import torch


#Define a project --> Destination directory for all results
project = "E:\\University\\Finalproject\BeeCount\\Main\\Yolo\\Results\\512"
#Define subdirectory for this specific training
name = "full_200_epochs_173_batch_4" 

# Load a model
model = YOLO("yolo11s-seg.yaml")  # build a new model from YAML
model = YOLO("yolo11s-seg.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11s-seg.yaml").load("yolo11s.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data='E:\\University\\Finalproject\BeeCount\\Main\\Yolo\\Dataset\\80.10.10\\G3awE7I0R3Z2.v173i.yolov11\\data.yaml',
                      project=project,
                      name=name,
                      epochs=200,
                      patience=0, #setting patience=0 to disable early stopping.
                      batch=4,
                      imgsz=512,  
                    )

# %% [markdown]
# ---

# %% [markdown]
# 256

# %%
import torch
print(torch.cuda.is_available())

if 'model' in globals():
    del model

torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
import os
from ultralytics import YOLO
# %matplotlib inline
from matplotlib import pyplot as plt
from PIL import Image

import torch


#Define a project --> Destination directory for all results
project = "E:\\University\\Finalproject\BeeCount\\Main\\Yolo\\Results\\256"
#Define subdirectory for this specific training
name = "full_200_epochs_174_batch_4" 

# Load a model
model = YOLO("yolo11s-seg.yaml")  # build a new model from YAML
model = YOLO("yolo11s-seg.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11s-seg.yaml").load("yolo11s.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data='E:\\University\\Finalproject\BeeCount\\Main\\Yolo\\Dataset\\80.10.10\\G3awE7I0R3Z2.v174i.yolov11\\data.yaml',
                      project=project,
                      name=name,
                      epochs=200,
                      patience=0, #setting patience=0 to disable early stopping.
                      batch=4,
                      imgsz=256,  
                    )

# %% [markdown]
# ---
