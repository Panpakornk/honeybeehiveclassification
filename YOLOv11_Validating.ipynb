# %% [markdown]
# <a href="https://colab.research.google.com/github/bnsreenu/python_for_microscopists/blob/master/334_training_YOLO_V8_EM_platelets_converted_labels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\full_200_epochs_105_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.71  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Next gen\HNBCCC.v105i.yolov11\valid\labels.cache... 28 images, 0 backgrounds, 0 corrupt: 100%|██████████| 28/28 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Next gen\HNBCCC.v105i.yolov11\valid\images\_DSC4927_JPG.rf.340a708a6199bd8ae17262513f34f04f.jpg: 1 duplicate labels removed
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Next gen\HNBCCC.v105i.yolov11\valid\images\_DSC5099_JPG.rf.6c4fc6c532f534aeed2f2cf1a46c4a8e.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:05<00:00,  2.90s/it]
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\full_200_epochs_108_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.71  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Next gen\HNBCCC.v108i.yolov11\valid\labels.cache... 28 images, 0 backgrounds, 0 corrupt: 100%|██████████| 28/28 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Next gen\HNBCCC.v108i.yolov11\valid\images\_DSC4927_JPG.rf.340a708a6199bd8ae17262513f34f04f.jpg: 1 duplicate labels removed
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Next gen\HNBCCC.v108i.yolov11\valid\images\_DSC5099_JPG.rf.6c4fc6c532f534aeed2f2cf1a46c4a8e.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.91s/it]
# ...

# %% [markdown]
# Compare with

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\full_200_epochs_133_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val(save=False)  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.71  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v133i.yolov11\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v133i.yolov11\valid\images\_DSC5138-Custom-Custom-.rf.18c1de121a829b58d1671bc73063eb06.jpg: 1 duplicate labels removed
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v133i.yolov11\valid\images\_DSC5214-Custom-Custom-.rf.183444a7d7bbfae15495312ceaa379cb.jpg: 1 duplicate labels removed
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\Full_150_epochs_150_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.71  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v150i.yolov11\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v150i.yolov11\valid\images\_DSC5035_JPG.rf.a5fae9b42e033777895f7bffd24aec71.jpg: 3 duplicate labels removed
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v150i.yolov11\valid\images\_DSC5099_JPG.rf.6c4fc6c532f534aeed2f2cf1a46c4a8e.jpg: 1 duplicate labels removed
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\Full_150_epochs_151_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.71  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v151i.yolov11\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v151i.yolov11\valid\images\_DSC5035_JPG.rf.a5fae9b42e033777895f7bffd24aec71.jpg: 3 duplicate labels removed
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v151i.yolov11\valid\images\_DSC5099_JPG.rf.6c4fc6c532f534aeed2f2cf1a46c4a8e.jpg: 1 duplicate labels removed
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\Full_150_epochs_152_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.71  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v152i.yolov11\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v152i.yolov11\valid\images\_DSC5035_JPG.rf.a5fae9b42e033777895f7bffd24aec71.jpg: 3 duplicate labels removed
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v152i.yolov11\valid\images\_DSC5099_JPG.rf.6c4fc6c532f534aeed2f2cf1a46c4a8e.jpg: 1 duplicate labels removed
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\Full_100_epochs_150_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.71  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v150i.yolov11\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v150i.yolov11\valid\images\_DSC5035_JPG.rf.a5fae9b42e033777895f7bffd24aec71.jpg: 3 duplicate labels removed
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v150i.yolov11\valid\images\_DSC5099_JPG.rf.6c4fc6c532f534aeed2f2cf1a46c4a8e.jpg: 1 duplicate labels removed
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\Full_100_epochs_151_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.71  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v151i.yolov11\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v151i.yolov11\valid\images\_DSC5035_JPG.rf.a5fae9b42e033777895f7bffd24aec71.jpg: 3 duplicate labels removed
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v151i.yolov11\valid\images\_DSC5099_JPG.rf.6c4fc6c532f534aeed2f2cf1a46c4a8e.jpg: 1 duplicate labels removed
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\Full_100_epochs_152_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.71  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v152i.yolov11\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v152i.yolov11\valid\images\_DSC5035_JPG.rf.a5fae9b42e033777895f7bffd24aec71.jpg: 3 duplicate labels removed
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v152i.yolov11\valid\images\_DSC5099_JPG.rf.6c4fc6c532f534aeed2f2cf1a46c4a8e.jpg: 1 duplicate labels removed
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s-seg.pt")  # load an official model
model = YOLO("E:\\University\\Finalproject\\BeeCount\\Main\\Yolo\Results\\960\\Full_200_epochs_153_batch_4\\weights\\best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps  # a list contains map50-95(B) of each category
metrics.seg.map  # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps  # a list contains map50-95(M) of each category
# Out:
# Ultralytics 8.3.73  Python-3.10.13 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11s-seg summary (fused): 265 layers, 10,067,977 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v153i.yolov11\valid\labels.cache... 15 images, 0 backgrounds, 0 corrupt: 100%|██████████| 15/15 [00:00<?, ?it/s]
# val: WARNING  E:\University\Finalproject\BeeCount\Main\Yolo\Dataset\Add last months\G3awE7I0R3Z2.v153i.yolov11\valid\images\_DSC5099_JPG.rf.532ac233fb0a890a5d758993ef822b06.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:21<00:00, 21.45s/it]
#                    all         15       2684      0.833      0.868      0.863      0.705      0.818      0.849      0.836      0.583
# ...
